# %% [markdown]
# <a href="https://colab.research.google.com/github/sankets139/AI_Engineering/blob/master/Visualization_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.) Import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2.) Upload the file
from google.colab import files
d = files.upload()
# Out:
#      <input type="file" id="files-b3f4ab11-266f-44b6-933c-bc181a121745" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3f4ab11-266f-44b6-933c-bc181a121745">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read the dataset/file
df_paris_housing = pd.read_csv('ParisHousingClass.csv')
df_paris_housing
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
df_paris_housing.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price category
# ...

# %% [markdown]
# # Scatterplot Charts

# %%
sns.scatterplot(data=df_paris_housing,x='cityPartRange',y='numPrevOwners',hue='category')
# Out:
# <Axes: xlabel='cityPartRange', ylabel='numPrevOwners'>

# %% [markdown]
# From the above chart shows most of the houses belong to the **Basic Category**.

# %%
sns.barplot(data=df_paris_housing,x='cityPartRange',y='numPrevOwners',hue='isNewBuilt')
# Out:
# <Axes: xlabel='cityPartRange', ylabel='numPrevOwners'>

# %%
df_paris_housing.columns
# Out:
# Index(['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price', 'category'],
#       dtype='object')

# %%
sns.barplot(data=df_paris_housing,x='numberOfRooms',y='isNewBuilt',hue='numPrevOwners',orient='h')
# Out:
# <Axes: xlabel='numberOfRooms', ylabel='isNewBuilt'>

# %% [markdown]
# # Countplot Chart

# %%
sns.countplot(data=df_paris_housing,x='numPrevOwners')
# Out:
# <Axes: xlabel='numPrevOwners', ylabel='count'>

# %% [markdown]
# # Boxplot Chart

# %%
sns.boxplot(data=df_paris_housing,x='numPrevOwners',y='price')
# Out:
# <Axes: xlabel='numPrevOwners', ylabel='price'>

# %%
sns.boxplot(data=df_paris_housing,x='category',y='price')
# Out:
# <Axes: xlabel='category', ylabel='price'>
